# %%
import os
import sys

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project Root:", project_root)
# Out:
# Project Root: /home/akash/Projects/Altrodav

# %%
from src.data import load_data, split_data
from src.features import prepare_features
from src.model import build_model, train_model
from src.evaluate import evaluate_model
from src.config import CONFIG

# %%
df = load_data()

print("Dataset Shape:", df.shape)

df.head()
# Out:
# Dataset Shape: (150, 5)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X_train, X_val, X_test, y_train, y_val, y_test = split_data(df)

print("Training Set  :", X_train.shape)
print("Validation Set:", X_val.shape)
print("Test Set      :", X_test.shape)
# Out:
# Training Set  : (105, 4)
# Validation Set: (22, 4)
# Test Set      : (23, 4)

# %%
X_train = prepare_features(X_train)
X_val = prepare_features(X_val)
X_test = prepare_features(X_test)

print("Feature preparation completed successfully!")
# Out:
# Feature preparation completed successfully!

# %%
model = build_model()

print(model)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
model = train_model(model, X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
accuracy = evaluate_model(model, X_test, y_test)

print(f"Baseline Accuracy: {accuracy:.4f}")
# Out:
# Baseline Accuracy: 0.3043

# %%
import pandas as pd

log = pd.DataFrame({
    "Model": [type(model).__name__],
    "Accuracy": [accuracy]
})

log.to_csv(CONFIG["experiment_log"], index=False)

print("Experiment log saved successfully!")
# Out:
# Experiment log saved successfully!

# %%
import pandas as pd

pd.read_csv(CONFIG["experiment_log"])
# Out:
#              Model  Accuracy
# 0  DummyClassifier  0.304348

# %% [markdown]
# # Task 03 - Core Architecture
#
# ## Conclusion
#
# - Built a modular ML project architecture.
# - Used separate modules for data, features, model, and evaluation.
# - Managed parameters using a central configuration file.
# - Trained and evaluated a baseline model.
# - Saved experiment metrics to a CSV log.
